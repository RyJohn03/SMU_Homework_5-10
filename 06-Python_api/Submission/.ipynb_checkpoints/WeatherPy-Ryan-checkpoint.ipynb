# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 576

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | aasiaat
# Processing Record 3 of Set 1 | cova figueira
# Processing Record 4 of Set 1 | kataragama
# City not found. Skipping...
# Processing Record 5 of Set 1 | bilibino
# Processing Record 6 of Set 1 | walvis bay
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | auki
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | okha
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | port mathurin
# Processing Record 13 of Set 1 | santa rosalia
# Processing Record 14 of Set 1 | zacualtipan
# Processing Record 15 of Set 1 | edinburgh of the seven seas
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | pacific grove
# Processing Record 18 of Set 1 | aleg
# Processing Record 19 of Set 1 | rongelap
# Processing Record 20 of Set 1 | mboursou lere
# Processing Record 21 of Set 1 | west island
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | sao joao da barra
# Processing Record 24 of Set 1 | el nido
# Processing Record 25 of Set 1 | utrik
# Processing Record 26 of Set 1 | bethanie
# Processing Record 27 of Set 1 | st. john's
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | hobyo
# Processing Record 30 of Set 1 | levuka
# Processing Record 31 of Set 1 | fort st. john
# Processing Record 32 of Set 1 | olonkinbyen
# Processing Record 33 of Set 1 | guiyang
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | stanley
# Processing Record 36 of Set 1 | gobabis
# Processing Record 37 of Set 1 | tazovsky
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | anadyr
# Processing Record 42 of Set 1 | palmer
# Processing Record 43 of Set 1 | alaghsas
# Processing Record 44 of Set 1 | bhimunipatnam
# Processing Record 45 of Set 1 | adamstown
# Processing Record 46 of Set 1 | lukoyanov
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | jabat
# Processing Record 50 of Set 1 | callao
# Processing Record 0 of Set 2 | bernay
# Processing Record 1 of Set 2 | saguenay
# Processing Record 2 of Set 2 | blackmans bay
# Processing Record 3 of Set 2 | akureyri
# Processing Record 4 of Set 2 | chibougamau
# Processing Record 5 of Set 2 | oristano
# Processing Record 6 of Set 2 | papatowai
# Processing Record 7 of Set 2 | kailua-kona
# Processing Record 8 of Set 2 | vilyuchinsk
# Processing Record 9 of Set 2 | keflavik
# Processing Record 10 of Set 2 | galle
# Processing Record 11 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 12 of Set 2 | 'aqrah
# City not found. Skipping...
# Processing Record 13 of Set 2 | margaret river
# Processing Record 14 of Set 2 | pont rouge
# Processing Record 15 of Set 2 | hechuan
# Processing Record 16 of Set 2 | afaahiti
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | kangding
# Processing Record 19 of Set 2 | wuwei
# Processing Record 20 of Set 2 | ola
# Processing Record 21 of Set 2 | grytviken
# Processing Record 22 of Set 2 | susuman
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | broken hill
# Processing Record 25 of Set 2 | timmins
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | mount isa
# Processing Record 28 of Set 2 | kingston
# Processing Record 29 of Set 2 | mitu
# Processing Record 30 of Set 2 | kununurra
# Processing Record 31 of Set 2 | rehoboth
# Processing Record 32 of Set 2 | bukama
# Processing Record 33 of Set 2 | karbala
# Processing Record 34 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 35 of Set 2 | ponta delgada
# Processing Record 36 of Set 2 | frontera
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | ar rayyan
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | colonia
# Processing Record 41 of Set 2 | uturoa
# Processing Record 42 of Set 2 | laredo
# Processing Record 43 of Set 2 | bam
# Processing Record 44 of Set 2 | karasburg
# Processing Record 45 of Set 2 | wailua homesteads
# Processing Record 46 of Set 2 | aykhal
# Processing Record 47 of Set 2 | weno
# Processing Record 48 of Set 2 | longmen
# Processing Record 49 of Set 2 | puerto natales
# Processing Record 0 of Set 3 | ostersund
# Processing Record 1 of Set 3 | ust-nera
# Processing Record 2 of Set 3 | kodinsk
# Processing Record 3 of Set 3 | srandakan
# Processing Record 4 of Set 3 | natal
# Processing Record 5 of Set 3 | korla
# Processing Record 6 of Set 3 | badger
# Processing Record 7 of Set 3 | haiku-pauwela
# Processing Record 8 of Set 3 | onega
# Processing Record 9 of Set 3 | new norfolk
# Processing Record 10 of Set 3 | tura
# Processing Record 11 of Set 3 | la'ie
# Processing Record 12 of Set 3 | lumajang
# Processing Record 13 of Set 3 | antsiranana
# Processing Record 14 of Set 3 | mossel bay
# Processing Record 15 of Set 3 | toliara
# Processing Record 16 of Set 3 | enewetak
# Processing Record 17 of Set 3 | leninskiy
# Processing Record 18 of Set 3 | isafjordur
# Processing Record 19 of Set 3 | arkalyk
# Processing Record 20 of Set 3 | keetmanshoop
# Processing Record 21 of Set 3 | codrington
# Processing Record 22 of Set 3 | acapulco de juarez
# Processing Record 23 of Set 3 | hadibu
# Processing Record 24 of Set 3 | carutapera
# Processing Record 25 of Set 3 | sassandra
# Processing Record 26 of Set 3 | martapura
# Processing Record 27 of Set 3 | brisas de zicatela
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | saratamata
# City not found. Skipping...
# Processing Record 31 of Set 3 | potchefstroom
# Processing Record 32 of Set 3 | iskateley
# Processing Record 33 of Set 3 | soe
# Processing Record 34 of Set 3 | selsey
# Processing Record 35 of Set 3 | nemuro
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | gejiu
# Processing Record 38 of Set 3 | gwadar
# Processing Record 39 of Set 3 | san patricio
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | orcopampa
# Processing Record 42 of Set 3 | constantia
# Processing Record 43 of Set 3 | el porvenir
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | bayan nur
# City not found. Skipping...
# Processing Record 46 of Set 3 | invercargill
# Processing Record 47 of Set 3 | howrah
# Processing Record 48 of Set 3 | sisimiut
# Processing Record 49 of Set 3 | lebu
# Processing Record 0 of Set 4 | isangel
# Processing Record 1 of Set 4 | piti village
# Processing Record 2 of Set 4 | pyhajarvi
# Processing Record 3 of Set 4 | hermanus
# Processing Record 4 of Set 4 | kerikeri
# Processing Record 5 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 6 of Set 4 | hamilton
# Processing Record 7 of Set 4 | karagandy
# Processing Record 8 of Set 4 | atafu village
# Processing Record 9 of Set 4 | mogocha
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | udachny
# Processing Record 13 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 14 of Set 4 | kapuskasing
# Processing Record 15 of Set 4 | soroti
# Processing Record 16 of Set 4 | darien
# Processing Record 17 of Set 4 | wainwright
# Processing Record 18 of Set 4 | santona
# Processing Record 19 of Set 4 | hiratacho
# Processing Record 20 of Set 4 | haapajarvi
# Processing Record 21 of Set 4 | kruisfontein
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | peace river
# Processing Record 24 of Set 4 | cruzilia
# Processing Record 25 of Set 4 | arraial do cabo
# Processing Record 26 of Set 4 | sarai naurang
# Processing Record 27 of Set 4 | tazacorte
# Processing Record 28 of Set 4 | jacmel
# Processing Record 29 of Set 4 | lajere
# Processing Record 30 of Set 4 | la passe
# Processing Record 31 of Set 4 | mersing
# Processing Record 32 of Set 4 | kirakira
# Processing Record 33 of Set 4 | minas de marcona
# Processing Record 34 of Set 4 | zelenogradsk
# Processing Record 35 of Set 4 | klyuchi
# Processing Record 36 of Set 4 | mount pearl
# Processing Record 37 of Set 4 | flekkefjord
# Processing Record 38 of Set 4 | jamestown
# Processing Record 39 of Set 4 | san antonio de pale
# Processing Record 40 of Set 4 | solleftea
# Processing Record 41 of Set 4 | ambato boeny
# Processing Record 42 of Set 4 | coquimbo
# Processing Record 43 of Set 4 | dudinka
# Processing Record 44 of Set 4 | lincheng
# Processing Record 45 of Set 4 | vrontados
# Processing Record 46 of Set 4 | pontyclun
# Processing Record 47 of Set 4 | pathein
# Processing Record 48 of Set 4 | plettenberg bay
# Processing Record 49 of Set 4 | yuktae-dong
# Processing Record 0 of Set 5 | beipiao
# Processing Record 1 of Set 5 | bowen
# Processing Record 2 of Set 5 | qaqortoq
# Processing Record 3 of Set 5 | cafayate
# Processing Record 4 of Set 5 | chernyshevskiy
# Processing Record 5 of Set 5 | pervomayskiy
# Processing Record 6 of Set 5 | kasongo-lunda
# Processing Record 7 of Set 5 | christchurch
# Processing Record 8 of Set 5 | oppdal
# Processing Record 9 of Set 5 | whitehorse
# Processing Record 10 of Set 5 | tegueste
# Processing Record 11 of Set 5 | san sebastian de la gomera
# Processing Record 12 of Set 5 | puerto baquerizo moreno
# Processing Record 13 of Set 5 | tabou
# Processing Record 14 of Set 5 | saudarkrokur
# Processing Record 15 of Set 5 | ambagarh chauki
# Processing Record 16 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 5 | filadelfia
# Processing Record 18 of Set 5 | puerto ayacucho
# Processing Record 19 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 20 of Set 5 | menongue
# Processing Record 21 of Set 5 | saipan
# Processing Record 22 of Set 5 | baissa
# Processing Record 23 of Set 5 | kuala belait
# Processing Record 24 of Set 5 | salahonda
# Processing Record 25 of Set 5 | muroto-misakicho
# Processing Record 26 of Set 5 | carnarvon
# Processing Record 27 of Set 5 | gadzhiyevo
# Processing Record 28 of Set 5 | sungailiat
# Processing Record 29 of Set 5 | chui
# Processing Record 30 of Set 5 | taksimo
# Processing Record 31 of Set 5 | khark
# Processing Record 32 of Set 5 | fale old settlement
# Processing Record 33 of Set 5 | talnakh
# Processing Record 34 of Set 5 | bomi
# Processing Record 35 of Set 5 | saint-pierre
# Processing Record 36 of Set 5 | itoman
# Processing Record 37 of Set 5 | cockburn town
# Processing Record 38 of Set 5 | newman
# Processing Record 39 of Set 5 | siteki
# Processing Record 40 of Set 5 | puerto ayora
# Processing Record 41 of Set 5 | loen
# Processing Record 42 of Set 5 | nar'yan-mar
# Processing Record 43 of Set 5 | terbuny
# Processing Record 44 of Set 5 | limassol
# Processing Record 45 of Set 5 | arno
# Processing Record 46 of Set 5 | conceicao da barra
# Processing Record 47 of Set 5 | garcia
# Processing Record 48 of Set 5 | hithadhoo
# Processing Record 49 of Set 5 | alofi
# Processing Record 0 of Set 6 | mizdah
# Processing Record 1 of Set 6 | kangiwa
# Processing Record 2 of Set 6 | kalaleh
# Processing Record 3 of Set 6 | dunbar
# Processing Record 4 of Set 6 | naze
# Processing Record 5 of Set 6 | bengkulu
# Processing Record 6 of Set 6 | camiri
# Processing Record 7 of Set 6 | inderbor
# Processing Record 8 of Set 6 | ribeira grande
# Processing Record 9 of Set 6 | fuli
# Processing Record 10 of Set 6 | tolanaro
# Processing Record 11 of Set 6 | yenotayevka
# Processing Record 12 of Set 6 | valdivia
# Processing Record 13 of Set 6 | nuuk
# Processing Record 14 of Set 6 | freetown
# Processing Record 15 of Set 6 | bontang
# Processing Record 16 of Set 6 | rio grande
# Processing Record 17 of Set 6 | majene
# Processing Record 18 of Set 6 | mejit
# Processing Record 19 of Set 6 | ouesso
# Processing Record 20 of Set 6 | savanna-la-mar
# Processing Record 21 of Set 6 | kresek
# Processing Record 22 of Set 6 | santa rosa del sur
# Processing Record 23 of Set 6 | madang
# Processing Record 24 of Set 6 | dabakala
# Processing Record 25 of Set 6 | manmad
# Processing Record 26 of Set 6 | ambon
# Processing Record 27 of Set 6 | guarapari
# Processing Record 28 of Set 6 | ntchisi
# Processing Record 29 of Set 6 | dunedin
# Processing Record 30 of Set 6 | bhimavaram
# Processing Record 31 of Set 6 | sengkang
# Processing Record 32 of Set 6 | baiti
# Processing Record 33 of Set 6 | bazou
# Processing Record 34 of Set 6 | puerto aysen
# Processing Record 35 of Set 6 | hawaiian paradise park
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | elamanchili
# Processing Record 38 of Set 6 | cueibet
# City not found. Skipping...
# Processing Record 39 of Set 6 | tambopata
# Processing Record 40 of Set 6 | taulaga
# Processing Record 41 of Set 6 | reggane
# Processing Record 42 of Set 6 | olavarria
# Processing Record 43 of Set 6 | fort bragg
# Processing Record 44 of Set 6 | queenstown
# Processing Record 45 of Set 6 | esmeraldas
# Processing Record 46 of Set 6 | nantucket
# Processing Record 47 of Set 6 | kimbe
# Processing Record 48 of Set 6 | pimentel
# Processing Record 49 of Set 6 | san luis de la loma
# Processing Record 0 of Set 7 | pombas
# Processing Record 1 of Set 7 | amory
# Processing Record 2 of Set 7 | katsuura
# Processing Record 3 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 4 of Set 7 | hermiston
# Processing Record 5 of Set 7 | arkhangel'sk
# Processing Record 6 of Set 7 | morehead city
# Processing Record 7 of Set 7 | lihue
# Processing Record 8 of Set 7 | kroya
# Processing Record 9 of Set 7 | tralee
# Processing Record 10 of Set 7 | zhicheng
# Processing Record 11 of Set 7 | mount gambier
# Processing Record 12 of Set 7 | hirara
# Processing Record 13 of Set 7 | gabu
# Processing Record 14 of Set 7 | manggar
# Processing Record 15 of Set 7 | nuku'alofa
# Processing Record 16 of Set 7 | vadso
# Processing Record 17 of Set 7 | sawai madhopur
# Processing Record 18 of Set 7 | korsakov
# Processing Record 19 of Set 7 | kidal
# Processing Record 20 of Set 7 | perugorria
# Processing Record 21 of Set 7 | argo
# Processing Record 22 of Set 7 | island harbour
# Processing Record 23 of Set 7 | broome
# Processing Record 24 of Set 7 | brookings
# Processing Record 25 of Set 7 | encamp
# Processing Record 26 of Set 7 | papao
# Processing Record 27 of Set 7 | pisco
# Processing Record 28 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 29 of Set 7 | ridgecrest
# Processing Record 30 of Set 7 | 'ain deheb
# Processing Record 31 of Set 7 | lepsy
# Processing Record 32 of Set 7 | madhyapur thimi
# City not found. Skipping...
# Processing Record 33 of Set 7 | villa gesell
# Processing Record 34 of Set 7 | labrador city
# Processing Record 35 of Set 7 | al artawiyah
# Processing Record 36 of Set 7 | palmerston
# Processing Record 37 of Set 7 | happy valley-goose bay
# Processing Record 38 of Set 7 | laguna
# Processing Record 39 of Set 7 | inhambane
# Processing Record 40 of Set 7 | ancud
# Processing Record 41 of Set 7 | granby
# Processing Record 42 of Set 7 | puerto deseado
# Processing Record 43 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 44 of Set 7 | tsiombe
# Processing Record 45 of Set 7 | lagoa
# Processing Record 46 of Set 7 | aflao
# Processing Record 47 of Set 7 | ryotsu-minato
# Processing Record 48 of Set 7 | horta
# Processing Record 49 of Set 7 | kavaratti
# Processing Record 0 of Set 8 | taro
# Processing Record 1 of Set 8 | hwange
# Processing Record 2 of Set 8 | vikulovo
# Processing Record 3 of Set 8 | honiara
# Processing Record 4 of Set 8 | makar'yev
# Processing Record 5 of Set 8 | bamboo flat
# Processing Record 6 of Set 8 | egilsstadir
# Processing Record 7 of Set 8 | cidreira
# Processing Record 8 of Set 8 | aral
# Processing Record 9 of Set 8 | margate
# Processing Record 10 of Set 8 | khandyga
# Processing Record 11 of Set 8 | luanda
# Processing Record 12 of Set 8 | ar rutbah
# Processing Record 13 of Set 8 | mugia
# Processing Record 14 of Set 8 | camarinas
# Processing Record 15 of Set 8 | novodvinsk
# Processing Record 16 of Set 8 | gadani
# Processing Record 17 of Set 8 | paita
# Processing Record 18 of Set 8 | coyhaique
# Processing Record 19 of Set 8 | siwa oasis
# Processing Record 20 of Set 8 | howard springs
# Processing Record 21 of Set 8 | cambria
# Processing Record 22 of Set 8 | reuleuet
# Processing Record 23 of Set 8 | etalle
# Processing Record 24 of Set 8 | dhanaula
# Processing Record 25 of Set 8 | markovo
# Processing Record 26 of Set 8 | vera cruz
# Processing Record 27 of Set 8 | bubaque
# Processing Record 28 of Set 8 | namibe
# Processing Record 29 of Set 8 | pilis
# Processing Record 30 of Set 8 | darwin
# Processing Record 31 of Set 8 | yanta
# Processing Record 32 of Set 8 | kourou
# Processing Record 33 of Set 8 | kijang
# Processing Record 34 of Set 8 | soligalich
# Processing Record 35 of Set 8 | vilyuysk
# Processing Record 36 of Set 8 | laojunmiao
# Processing Record 37 of Set 8 | espargos
# City not found. Skipping...
# Processing Record 38 of Set 8 | miquelon
# Processing Record 39 of Set 8 | orzu
# Processing Record 40 of Set 8 | manicore
# Processing Record 41 of Set 8 | tamale
# Processing Record 42 of Set 8 | nova sintra
# Processing Record 43 of Set 8 | shortandy
# Processing Record 44 of Set 8 | minab
# Processing Record 45 of Set 8 | tarko-sale
# Processing Record 46 of Set 8 | goundi
# Processing Record 47 of Set 8 | severo-yeniseyskiy
# Processing Record 48 of Set 8 | galeana
# Processing Record 49 of Set 8 | sabang
# Processing Record 0 of Set 9 | bull savanna
# Processing Record 1 of Set 9 | sragen
# Processing Record 2 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 9 | morant bay
# Processing Record 4 of Set 9 | banchory
# Processing Record 5 of Set 9 | remire-montjoly
# Processing Record 6 of Set 9 | lodja
# Processing Record 7 of Set 9 | soure
# Processing Record 8 of Set 9 | creston
# Processing Record 9 of Set 9 | nazir town
# Processing Record 10 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 11 of Set 9 | crucecita
# Processing Record 12 of Set 9 | karatau
# Processing Record 13 of Set 9 | yaren
# Processing Record 14 of Set 9 | san rafael del yuma
# Processing Record 15 of Set 9 | leticia
# Processing Record 16 of Set 9 | havre
# Processing Record 17 of Set 9 | mont-dore
# Processing Record 18 of Set 9 | vorgashor
# Processing Record 19 of Set 9 | hammerfest
# Processing Record 20 of Set 9 | dire dawa
# Processing Record 21 of Set 9 | kristiansund
# Processing Record 22 of Set 9 | pala
# Processing Record 23 of Set 9 | poltavka
# Processing Record 24 of Set 9 | arauca
# Processing Record 25 of Set 9 | hailar
# Processing Record 26 of Set 9 | fortuna
# Processing Record 27 of Set 9 | purpe
# Processing Record 28 of Set 9 | malpe
# Processing Record 29 of Set 9 | vernon
# Processing Record 30 of Set 9 | jabor
# Processing Record 31 of Set 9 | sturgeon bay
# Processing Record 32 of Set 9 | vila franca do campo
# Processing Record 33 of Set 9 | severnoye
# Processing Record 34 of Set 9 | crane
# Processing Record 35 of Set 9 | nogliki
# Processing Record 36 of Set 9 | kiruna
# Processing Record 37 of Set 9 | altay
# Processing Record 38 of Set 9 | poso
# Processing Record 39 of Set 9 | el bolson
# Processing Record 40 of Set 9 | obo
# Processing Record 41 of Set 9 | pechora
# Processing Record 42 of Set 9 | nkurenkuru
# City not found. Skipping...
# Processing Record 43 of Set 9 | rundu
# Processing Record 44 of Set 9 | sao vicente
# Processing Record 45 of Set 9 | shahrak
# Processing Record 46 of Set 9 | berdigestyakh
# Processing Record 47 of Set 9 | yatou
# Processing Record 48 of Set 9 | plouzane
# Processing Record 49 of Set 9 | isiro
# Processing Record 0 of Set 10 | skoropuskovskiy
# Processing Record 1 of Set 10 | pavlodar
# Processing Record 2 of Set 10 | nema
# Processing Record 3 of Set 10 | xiuying
# City not found. Skipping...
# Processing Record 4 of Set 10 | khash
# Processing Record 5 of Set 10 | belmonte
# Processing Record 6 of Set 10 | kitimat
# Processing Record 7 of Set 10 | san borja
# Processing Record 8 of Set 10 | balqash
# Processing Record 9 of Set 10 | swan hill
# Processing Record 10 of Set 10 | shenjiamen
# Processing Record 11 of Set 10 | veraval
# Processing Record 12 of Set 10 | tasova
# Processing Record 13 of Set 10 | ust'-ilimsk
# Processing Record 14 of Set 10 | polyarnyy
# Processing Record 15 of Set 10 | bodo
# Processing Record 16 of Set 10 | selfoss
# Processing Record 17 of Set 10 | les sables-d'olonne
# Processing Record 18 of Set 10 | sola
# Processing Record 19 of Set 10 | pandan
# Processing Record 20 of Set 10 | grand falls-windsor
# Processing Record 21 of Set 10 | ulety
# Processing Record 22 of Set 10 | kupang
# Processing Record 23 of Set 10 | heide
# Processing Record 24 of Set 10 | flying fish cove
# Processing Record 25 of Set 10 | porto novo
# Processing Record 26 of Set 10 | guiuan
# Processing Record 27 of Set 10 | kenai
# Processing Record 28 of Set 10 | hassi messaoud
# Processing Record 29 of Set 10 | sao jose da coroa grande
# Processing Record 30 of Set 10 | kyren
# Processing Record 31 of Set 10 | al qusayr
# Processing Record 32 of Set 10 | ijuw
# City not found. Skipping...
# Processing Record 33 of Set 10 | myaydo
# Processing Record 34 of Set 10 | samho-rodongjagu
# Processing Record 35 of Set 10 | iguatemi
# Processing Record 36 of Set 10 | bikenibeu village
# Processing Record 37 of Set 10 | valparaiso
# Processing Record 38 of Set 10 | kipushi
# Processing Record 39 of Set 10 | harpalpur
# Processing Record 40 of Set 10 | alice springs
# Processing Record 41 of Set 10 | mahibadhoo
# Processing Record 42 of Set 10 | prince rupert
# Processing Record 43 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 44 of Set 10 | mingyue
# Processing Record 45 of Set 10 | kataba
# Processing Record 46 of Set 10 | mana
# Processing Record 47 of Set 10 | steinkjer
# Processing Record 48 of Set 10 | kapa'a
# Processing Record 49 of Set 10 | shimanovsk
# Processing Record 0 of Set 11 | hasaki
# Processing Record 1 of Set 11 | victoria point
# Processing Record 2 of Set 11 | ntoum
# Processing Record 3 of Set 11 | nizhniy kuranakh
# Processing Record 4 of Set 11 | amble
# Processing Record 5 of Set 11 | cold lake
# Processing Record 6 of Set 11 | ljusdal
# Processing Record 7 of Set 11 | zouerate
# Processing Record 8 of Set 11 | kiunga
# Processing Record 9 of Set 11 | villamontes
# Processing Record 10 of Set 11 | mooroopna
# Processing Record 11 of Set 11 | iquique
# Processing Record 12 of Set 11 | conduaga
# Processing Record 13 of Set 11 | harper
# Processing Record 14 of Set 11 | zhlobin
# Processing Record 15 of Set 11 | kyelang
# Processing Record 16 of Set 11 | yermolayevo
# Processing Record 17 of Set 11 | northam
# Processing Record 18 of Set 11 | ketchikan
# Processing Record 19 of Set 11 | al-`ula
# City not found. Skipping...
# Processing Record 20 of Set 11 | puri
# Processing Record 21 of Set 11 | kosh-agach
# Processing Record 22 of Set 11 | touros
# Processing Record 23 of Set 11 | lampa
# Processing Record 24 of Set 11 | hargeysa
# Processing Record 25 of Set 11 | amga
# Processing Record 26 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 27 of Set 11 | garwolin
# Processing Record 28 of Set 11 | luang namtha
# Processing Record 29 of Set 11 | port douglas
# Processing Record 30 of Set 11 | dundee
# Processing Record 31 of Set 11 | lonar
# Processing Record 32 of Set 11 | llandrindod wells
# Processing Record 33 of Set 11 | birobidzhan
# Processing Record 34 of Set 11 | roma
# Processing Record 35 of Set 11 | bardsir
# Processing Record 36 of Set 11 | ulladulla
# Processing Record 37 of Set 11 | saint-mandrier-sur-mer
# Processing Record 38 of Set 11 | sikonge
# Processing Record 39 of Set 11 | fontanelas
# Processing Record 40 of Set 11 | imbituba
# Processing Record 41 of Set 11 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 42 of Set 11 | turgen
# Processing Record 43 of Set 11 | berrotaran
# Processing Record 44 of Set 11 | magadan
# Processing Record 45 of Set 11 | caleta de carquin
# Processing Record 46 of Set 11 | tanout
# Processing Record 47 of Set 11 | kalmunai
# Processing Record 48 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 49 of Set 11 | teknaf
# Processing Record 0 of Set 12 | kish
# Processing Record 1 of Set 12 | chimore
# Processing Record 2 of Set 12 | port isabel
# Processing Record 3 of Set 12 | san martin
# Processing Record 4 of Set 12 | floro
# Processing Record 5 of Set 12 | markova
# Processing Record 6 of Set 12 | tsetserleg
# Processing Record 7 of Set 12 | benin city
# Processing Record 8 of Set 12 | roxborough park
# Processing Record 9 of Set 12 | ghadamis
# Processing Record 10 of Set 12 | antonio enes
# Processing Record 11 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 12 of Set 12 | tobruk
# Processing Record 13 of Set 12 | mahala
# Processing Record 14 of Set 12 | al wajh
# Processing Record 15 of Set 12 | quellon
# Processing Record 16 of Set 12 | port saint john's
# Processing Record 17 of Set 12 | raiwala bara
# Processing Record 18 of Set 12 | afif
# Processing Record 19 of Set 12 | nieuw amsterdam
# Processing Record 20 of Set 12 | darabani
# Processing Record 21 of Set 12 | malumfashi
# Processing Record 22 of Set 12 | kone
# Processing Record 23 of Set 12 | rockland
# Processing Record 24 of Set 12 | santa ana
# Processing Record 25 of Set 12 | ixtapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# # Secondary work with error handling
# rows = []

# # loop cities
# for city in cities:
    
#     try:

#         # geolocation
#         geo_url = f"http://api.openweathermap.org/geo/1.0/direct?q={city}&limit=1&appid={weather_api_key}"
#         response = requests.get(geo_url)

#         if (response.status_code == 200):
#             # do work
#             geo_data = response.json()

#             # get lat, lon, country, name
#             if len(geo_data) > 0:
#                 lat = geo_data[0].get("lat", np.nan)
#                 lon = geo_data[0].get("lon", np.nan)
#                 country = geo_data[0].get("country", None)
#                 name = geo_data[0].get("name", None)

#         #         print(f"{city} is located at {lat},{lon}")

#                 if (lat and lon):
#                     # weather
#                     weather_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={weather_api_key}&units=imperial"
#                     response2 = requests.get(weather_url)

#                     if (response2.status_code == 200):
#                         weather_data = response2.json()

#                         # extract data
#                         temp = weather_data.get("main", {}).get("temp", np.nan)
#                         pressure = weather_data.get("main", {}).get("pressure", np.nan)
#                         humidity = weather_data.get("main", {}).get("humidity", np.nan)
#                         wind_speed = weather_data.get("wind", {}).get("speed", np.nan)
#                         cloudiness = weather_data.get("clouds", {}).get("all", np.nan)
#                         date = wind_speed = weather_data.get("dt", np.nan)

#                         # build row
#                         row = {"city": name,
#                                "country": country,
#                                "latitude": lat,
#                                "longitude": lon,
#                                "temperature": temp,
#                                "pressure": pressure,
#                                "humidity": humidity,
#                                "wind_speed": wind_speed,
#                               "cloudiness": cloudiness,
#                               "date": date}

#                         #print(row)
#                         rows.append(row)

#                     else:
#                         print(f"Getting Weather Data failed with status code: {response2.status_code}. More info below:")
#                         print(weather_data)
#                 else:
#                     print("Failed to extract latitude and longitude from response.")
#                     print(geo_data)
#             else:
#                 print(f"Did not find any geolocation data for city: {city}")
#         else:
#             print(f"Getting geolocation data failed with status code: {response.status_code}. More info below:")
#             print(geo_data)
#     except Exception as e:
#         print(f"/Uh oh! Something went wrong for {city}")
#         print(e)
    
#     # sleep 
#     print(f"{city} was processed successfully.")
#     time.sleep(1)

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          550
# Lat           550
# Lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      3.21        88         100
# 1            aasiaat  68.7098  -52.8699      4.00        97         100
# 2      cova figueira  14.8905  -24.2934     22.40        80          95
# 3           bilibino  68.0546  166.4372     10.13        84         100
# 4         walvis bay -22.9575   14.5053     13.53        71           0
#
#    Wind Speed Country        Date
# 0       13.84      TF  1688455485
# 1        2.02      GL  1688455485
# 2        3.19      CV  1688455485
# 3        2.77      RU  1688455295
# 4        1.03      NA  1688455486

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      3.21        88         100
# 1                  aasiaat  68.7098  -52.8699      4.00        97         100
# 2            cova figueira  14.8905  -24.2934     22.40        80          95
# 3                 bilibino  68.0546  166.4372     10.13        84         100
# 4               walvis bay -22.9575   14.5053     13.53        71           0
#
#          Wind Speed Country        Date
# City_ID
# 0             13.84      TF  1688455485
# 1              2.02      GL  1688455485
# 2              3.19      CV  1688455485
# 3              2.77      RU  1688455295
# 4              1.03     NaN  1688455486

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
plt.figure(figsize=(10,6))

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], color="#AA5042", s=125)
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title("Latitude vs Temperature")
plt.grid(axis="both", color="lightgrey", linestyle="--", alpha=0.2)
plt.show()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
plt.figure(figsize=(10,6))

plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], color="#91B7C7", s=125)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs Humidity")
plt.grid(axis="both", color="lightgrey", linestyle="--", alpha=0.2)
plt.show()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
plt.figure(figsize=(10,6))

plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], color="#ADBABD", s=125)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs Cloudiness")
plt.grid(axis="both", color="lightgrey", linestyle="--", alpha=0.2)
plt.show()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
plt.figure(figsize=(10,6))

plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], color="#CAF0F8", s=125)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs Wind Speed")
plt.grid(axis="both", color="lightgrey", linestyle="--", alpha=0.2)
plt.show()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0].reset_index(drop=True)

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        aasiaat  68.7098  -52.8699     39.20        97         100
# 1  cova figueira  14.8905  -24.2934     72.32        80          95
# 2       bilibino  68.0546  166.4372     50.23        84         100
# 3           okha  53.5739  142.9478     55.76        78          19
# 4  santa rosalia  27.3167 -112.2833     80.76        60           0
#
#    Wind Speed Country        Date
# 0        4.52      GL  1688454782
# 1        7.14      CV  1688454782
# 2        6.20      RU  1688454783
# 3       11.43      RU  1688454785
# 4        6.06      MX  1688454786

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0].reset_index(drop=True)

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167     37.78        88         100
# 1         walvis bay -22.9575   14.5053     70.03        29           0
# 2           waitangi -43.9535 -176.5597     49.82        78          86
# 3               auki  -8.7676  160.7034     80.20        82          26
# 4            ushuaia -54.8000  -68.3000     33.46        75           0
#
#    Wind Speed Country        Date
# 0       30.96      TF  1688454782
# 1        7.67     NaN  1688454619
# 2       15.01      NZ  1688454525
# 3        7.05      SB  1688454784
# 4        2.30      AR  1688454784

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))
# Out:
# The r-value is: 0.32112177977265943

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))
# Out:
# The r-value is: 0.7616349995328608

# %% [markdown]
# **Discussion about the linear relationship:** Both northern and southern hemispheres show a strong relationship to temperature. Southern hemisphere examples a positive relationship and northern examples a negative relationship. The closer to the equator you get, the warmer the temperature becomes on average.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(6,-10))
# Out:
# The r-value is: 0.017558741558965134

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(6,-10))
# Out:
# The r-value is: 0.030779599322892842

# %% [markdown]
# **Discussion about the linear relationship:** No strong relationship seen.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness",(6,-10))
# Out:
# The r-value is: 0.007747693858019579

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness",(6,-10))
# Out:
# The r-value is: 0.029613158637825356

# %% [markdown]
# **Discussion about the linear relationship:** No strong relationship seen.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed",(6,-10))
# Out:
# The r-value is: 0.001757698222718539

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Wind Speed",(6,-10))
# Out:
# The r-value is: 0.029613158637825356

# %% [markdown]
# **Discussion about the linear relationship:** No strong relationship seen.
